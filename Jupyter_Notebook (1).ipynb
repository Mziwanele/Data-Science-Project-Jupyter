# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mziwanele__
# Student

# %% [markdown]
# _I am interested in Data Science because I want to improve on International Relations and Digital Democracy_

# %% [markdown]
# ###The code below will be doing addition

# %%
1+1
# Out:
# 2

# %% [markdown]
#  - Data
#  - Science
#  - Is
#  - Fun

# %% [markdown]
# 1. Keep
# 2. Trying
# 3. Your
# 4. Best

# %% [markdown]
# ![Eb_Qa0uXYAI2Se8.jpg](attachment:173405dd-1000-4d1f-a8c7-3ace6f615125.jpg)
